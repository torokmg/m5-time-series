# %% [markdown]
# ### Mount Data

# %%
# !cp /content/drive/My\ Drive/m5/m5-forecasting-accuracy.zip /content/

# %%
# !unzip /content/m5-forecasting-accuracy.zip
# Out:
# Archive:  /content/m5-forecasting-accuracy.zip
# replace calendar.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %% [markdown]
# ### Import dataset

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# %%
calendar_df = pd.read_csv('calendar.csv')
sell_prices_df = pd.read_csv('sell_prices.csv')
sales_train_validation_df = pd.read_csv('sales_train_validation.csv')

# %%
sales_train_validation_df.columns
# Out:
# Index(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id', 'd_1',
#        'd_2', 'd_3', 'd_4',
#        ...
#        'd_1904', 'd_1905', 'd_1906', 'd_1907', 'd_1908', 'd_1909', 'd_1910',
#        'd_1911', 'd_1912', 'd_1913'],
#       dtype='object', length=1919)

# %%
sales_train_validation_df
# Out:
#                                   id        item_id  ... d_1912 d_1913
# 0      HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  ...      1      1
# 1      HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  ...      0      0
# 2      HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  ...      1      1
# 3      HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  ...      7      2
# 4      HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  ...      2      4
# ...                              ...            ...  ...    ...    ...
# 30485    FOODS_3_823_WI_3_validation    FOODS_3_823  ...      0      1
# 30486    FOODS_3_824_WI_3_validation    FOODS_3_824  ...      1      0
# 30487    FOODS_3_825_WI_3_validation    FOODS_3_825  ...      1      0
# 30488    FOODS_3_826_WI_3_validation    FOODS_3_826  ...      1      3
# 30489    FOODS_3_827_WI_3_validation    FOODS_3_827  ...      0      0
#
# [30490 rows x 1919 columns]

# %%
sales_train_validation_df['item_id'].nunique()
# Out:
# 3049

# %%
sales_train_validation_df.groupby(['state_id', 'store_id', 'cat_id', 'dept_id', 'item_id']).mean()
# Out:
#                                                          d_1  ...  d_1913
# state_id store_id cat_id    dept_id     item_id               ...
# CA       CA_1     FOODS     FOODS_1     FOODS_1_001        3  ...       0
#                                         FOODS_1_002        0  ...       0
#                                         FOODS_1_003        0  ...       0
#                                         FOODS_1_004        0  ...       0
#                                         FOODS_1_005        3  ...       1
# ...                                                      ...  ...     ...
# WI       WI_3     HOUSEHOLD HOUSEHOLD_2 HOUSEHOLD_2_512    0  ...       0
#                                         HOUSEHOLD_2_513    0  ...       0
#                                         HOUSEHOLD_2_514    0  ...       0
#                                         HOUSEHOLD_2_515    0  ...       0
#                                         HOUSEHOLD_2_516    0  ...       0
#
# ...

# %% [markdown]
# ### Helper functions for reducing memory and label encoding
# https://www.kaggle.com/girmdshinsei/for-japanese-beginner-with-wrmsse-in-lgbm

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns: #columns毎に処理
        col_type = df[col].dtypes
        if col_type in numerics: #numericsのデータ型の範囲内のときに処理を実行. データの最大最小値を元にデータ型を効率的なものに変更
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
from sklearn.preprocessing import LabelEncoder
def encode_categorical(df, cols):
    
    for col in cols:
        # Leave NaN as it is.
        le = LabelEncoder()
        #not_null = df[col][df[col].notnull()]
        df[col] = df[col].fillna('nan')
        df[col] = pd.Series(le.fit_transform(df[col]), index=df.index)

    return df


calendar_df = encode_categorical(
    calendar_df, ["event_name_1", "event_type_1", "event_name_2", "event_type_2"]
).pipe(reduce_mem_usage)

sales_train_validation_df = encode_categorical(
    sales_train_validation_df, ["item_id", "dept_id", "cat_id", "store_id", "state_id"],
).pipe(reduce_mem_usage)

sell_prices_df = encode_categorical(sell_prices_df, ["item_id", "store_id"]).pipe(
    reduce_mem_usage
)
# Out:
# Mem. usage decreased to  0.07 Mb (66.9% reduction)
# Mem. usage decreased to 94.01 Mb (78.9% reduction)
# Mem. usage decreased to 45.67 Mb (78.1% reduction)

# %%
sales_train_validation_df.head()
# Out:
#                               id  item_id  dept_id  ...  d_1911  d_1912  d_1913
# 0  HOBBIES_1_001_CA_1_validation     1437        3  ...       0       1       1
# 1  HOBBIES_1_002_CA_1_validation     1438        3  ...       0       0       0
# 2  HOBBIES_1_003_CA_1_validation     1439        3  ...       1       1       1
# 3  HOBBIES_1_004_CA_1_validation     1440        3  ...       3       7       2
# 4  HOBBIES_1_005_CA_1_validation     1441        3  ...       2       2       4
#
# [5 rows x 1919 columns]

# %% [markdown]
# ## Melting and Merging

# %%
sales_train_validation_df.head()
# Out:
#                               id  item_id  dept_id  ...  d_1911  d_1912  d_1913
# 0  HOBBIES_1_001_CA_1_validation     1437        3  ...       0       1       1
# 1  HOBBIES_1_002_CA_1_validation     1438        3  ...       0       0       0
# 2  HOBBIES_1_003_CA_1_validation     1439        3  ...       1       1       1
# 3  HOBBIES_1_004_CA_1_validation     1440        3  ...       3       7       2
# 4  HOBBIES_1_005_CA_1_validation     1441        3  ...       2       2       4
#
# [5 rows x 1919 columns]

# %%
melted_df = pd.melt(sales_train_validation_df, id_vars=sales_train_validation_df.columns[:6], value_vars=sales_train_validation_df.columns[6:], var_name='d', value_name='demand')

# %%
melted_df
# Out:
#                                      id  item_id  ...       d  demand
# 0         HOBBIES_1_001_CA_1_validation     1437  ...     d_1       0
# 1         HOBBIES_1_002_CA_1_validation     1438  ...     d_1       0
# 2         HOBBIES_1_003_CA_1_validation     1439  ...     d_1       0
# 3         HOBBIES_1_004_CA_1_validation     1440  ...     d_1       0
# 4         HOBBIES_1_005_CA_1_validation     1441  ...     d_1       0
# ...                                 ...      ...  ...     ...     ...
# 58327365    FOODS_3_823_WI_3_validation     1432  ...  d_1913       1
# 58327366    FOODS_3_824_WI_3_validation     1433  ...  d_1913       0
# 58327367    FOODS_3_825_WI_3_validation     1434  ...  d_1913       0
# 58327368    FOODS_3_826_WI_3_validation     1435  ...  d_1913       3
# 58327369    FOODS_3_827_WI_3_validation     1436  ...  d_1913       0
#
# [58327370 rows x 8 columns]

# %%
melted_df = melted_df.merge(calendar_df, on='d', copy=False)

# %%
melted_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58327370 entries, 0 to 58327369
# Data columns (total 21 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   id            object
#  1   item_id       int16
#  2   dept_id       int8
#  3   cat_id        int8
#  4   store_id      int8
#  5   state_id      int8
#  6   d             object
#  7   demand        int16
#  8   date          object
#  9   wm_yr_wk      int16
#  10  weekday       object
#  11  wday          int8
#  12  month         int8
#  13  year          int16
#  14  event_name_1  int8
#  15  event_type_1  int8
#  16  event_name_2  int8
#  17  event_type_2  int8
#  18  snap_CA       int8
#  19  snap_TX       int8
#  20  snap_WI       int8
# dtypes: int16(4), int8(13), object(4)
# memory usage: 3.3+ GB

# %%
melted_df.head()
# Out:
#                               id  item_id  dept_id  ...  snap_CA  snap_TX  snap_WI
# 0  HOBBIES_1_001_CA_1_validation     1437        3  ...        0        0        0
# 1  HOBBIES_1_002_CA_1_validation     1438        3  ...        0        0        0
# 2  HOBBIES_1_003_CA_1_validation     1439        3  ...        0        0        0
# 3  HOBBIES_1_004_CA_1_validation     1440        3  ...        0        0        0
# 4  HOBBIES_1_005_CA_1_validation     1441        3  ...        0        0        0
#
# [5 rows x 21 columns]

# %%
# melted_df = pd.merge(melted_df, sell_prices_df, on=['item_id', 'wm_yr_wk'])

# %%
# melted_df['date'] = pd.to_datetime(melted_df['date'])
# melted_df.set_index('date', inplace=True)

# %%
melted_df.drop(['d', 'weekday'], axis=1, inplace=True)

# %%
melted_df.dtypes
# Out:
# id              object
# item_id          int16
# dept_id           int8
# cat_id            int8
# store_id          int8
# state_id          int8
# demand           int16
# date            object
# wm_yr_wk         int16
# wday              int8
# month             int8
# year             int16
# event_name_1      int8
# event_type_1      int8
# event_name_2      int8
# event_type_2      int8
# snap_CA           int8
# snap_TX           int8
# snap_WI           int8
# dtype: object

# %%
import lightgbm as lgbm

# %%
x_train = melted_df[melted_df['date'] <= '2016-03-27']
y_train = x_train['demand']
x_val = melted_df[(melted_df['date'] > '2016-03-27') & (melted_df['date'] <= '2016-04-24')]
y_val = x_val['demand']
test = melted_df[(melted_df['date'] > '2016-04-24')]

# %%
x_train['date']
# Out:
# 0           2011-01-29
# 1           2011-01-29
# 2           2011-01-29
# 3           2011-01-29
# 4           2011-01-29
#                ...
# 57473645    2016-03-27
# 57473646    2016-03-27
# 57473647    2016-03-27
# 57473648    2016-03-27
# 57473649    2016-03-27
# Name: date, Length: 57473650, dtype: object

# %%
print(f"start of x_train {x_train['date'].head(1).values}, end of x_train {x_train['date'].tail(1).values}")
print(f"start of x_train {x_val['date'].head(1).values}, end of x_train {x_val['date'].tail(1).values}")
print(f'size of test {test.shape[0]}')
# Out:
# start of x_train ['2011-01-29'], end of x_train ['2016-03-27']
# start of x_train ['2016-03-28'], end of x_train ['2016-04-24']
# size of test 0

# %%
features = [
 'item_id',
 'dept_id',
 'cat_id',
 'store_id',
 'state_id',
 'wm_yr_wk',
 'wday',
 'month',
 'year',
 'event_name_1',
 'event_type_1',
 'event_name_2',
 'event_type_2',
 'snap_CA',
 'snap_TX',
 'snap_WI']

# %%
params = {
    'boosting_type': 'gbdt',
    'metric': 'rmse',
    'objective': 'regression',
    'n_jobs': -1,
    'seed': 236,
    'learning_rate': 0.1,
    'bagging_fraction': 0.75,
    'bagging_freq': 10, 
    'colsample_bytree': 0.75}

# %%
train_lgbm = lgbm.Dataset(x_train[features], y_train)
val_lgbm = lgbm.Dataset(x_val[features], y_val)

# %%
from sklearn import metrics
model = lgbm.train(params, 
                   train_lgbm, 
                   num_boost_round = 2500, 
                   early_stopping_rounds = 50, 
                   valid_sets = [train_lgbm, val_lgbm], 
                   verbose_eval = 100)

val_pred = model.predict(x_val[features])
val_score = np.sqrt(metrics.mean_squared_error(val_pred, y_val))
print(f'Our val rmse score is {val_score}')

# %%
# y_pred = model.predict(test)
