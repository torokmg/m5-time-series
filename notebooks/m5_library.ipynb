# %% [markdown]
# ## Google Colab Setup
# Commands to mount data from drive to colab environment

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/My\ Drive/m5/*.pickle /content/

# %% [markdown]
# ## Load Store Data
# Load all of the data associated for the given store number

# %%
import pandas as pd
def load_store(store_id):
  """Loads from the project root directory"""
  return pd.read_pickle(f"./StoreID_{store_id}.pickle")

# %% [markdown]
# ### Single Store Data
# Read in DataFrame for store '0'

# %%
store_01_df = load_store('0')
store_01_df.head()
# Out:
#             wm_yr_wk  wday  month  year  ...  store_id  state_id  sold  sell_price
# date                                     ...
# 2011-01-29     11101     1      1  2011  ...         0         0     0         NaN
# 2011-01-29     11101     1      1  2011  ...         0         0     0         NaN
# 2011-01-29     11101     1      1  2011  ...         0         0     0         NaN
# 2011-01-29     11101     1      1  2011  ...         0         0     0         NaN
# 2011-01-29     11101     1      1  2011  ...         0         0     0         NaN
#
# [5 rows x 19 columns]

# %%
store_01_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6003481 entries, 2011-01-29 to 2016-06-19
# Data columns (total 19 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   wm_yr_wk      int16
#  1   wday          int8
#  2   month         int8
#  3   year          int16
#  4   event_name_1  int8
#  5   event_type_1  int8
#  6   event_name_2  int8
#  7   event_type_2  int8
#  8   snap_CA       int8
#  9   snap_TX       int8
#  10  snap_WI       int8
#  11  id            category
#  12  item_id       int16
#  13  dept_id       int8
#  14  cat_id        int8
#  15  store_id      int8
#  16  state_id      int8
#  17  sold          object
#  18  sell_price    float16
# dtypes: category(1), float16(1), int16(3), int8(13), object(1)
# memory usage: 224.8+ MB

# %% [markdown]
# ### Combined Dataset

# %%
df = load_store(0)
for idx in range(1, 10):
    df = pd.concat([df, load_store(idx)])

# %%
df
# Out:
#             wm_yr_wk  wday  month  year  ...  store_id  state_id  sold  sell_price
# date                                     ...
# 2011-01-29     11101     1      1  2011  ...         0         0     0         NaN
# 2011-01-29     11101     1      1  2011  ...         0         0     0         NaN
# 2011-01-29     11101     1      1  2011  ...         0         0     0         NaN
# 2011-01-29     11101     1      1  2011  ...         0         0     0         NaN
# 2011-01-29     11101     1      1  2011  ...         0         0     0         NaN
# ...              ...   ...    ...   ...  ...       ...       ...   ...         ...
# 2016-06-19     11621     2      6  2016  ...         9         2   NaN    2.980469
# 2016-06-19     11621     2      6  2016  ...         9         2   NaN    2.480469
# 2016-06-19     11621     2      6  2016  ...         9         2   NaN    3.980469
# 2016-06-19     11621     2      6  2016  ...         9         2   NaN    1.280273
# 2016-06-19     11621     2      6  2016  ...         9         2   NaN    1.000000
#
# [60034810 rows x 19 columns]

# %% [markdown]
# ## Feature Engineering
# Starter features from https://www.kaggle.com/ragnar123/very-fst-model

# %% [markdown]
# ### Time Features

# %%
def demand_fe(data):
    # rolling demand features
    data['lag_t28'] = data.groupby(['id'])['sold'].transform(lambda x: x.shift(28))
    data['lag_t29'] = data.groupby(['id'])['sold'].transform(lambda x: x.shift(29))
    data['lag_t30'] = data.groupby(['id'])['sold'].transform(lambda x: x.shift(30))
    data['rolling_mean_t7'] = data.groupby(['id'])['sold'].transform(lambda x: x.shift(28).rolling(7).mean())
    data['rolling_std_t7'] = data.groupby(['id'])['sold'].transform(lambda x: x.shift(28).rolling(7).std())
    data['rolling_mean_t30'] = data.groupby(['id'])['sold'].transform(lambda x: x.shift(28).rolling(30).mean())
    data['rolling_mean_t90'] = data.groupby(['id'])['sold'].transform(lambda x: x.shift(28).rolling(90).mean())
    data['rolling_mean_t180'] = data.groupby(['id'])['sold'].transform(lambda x: x.shift(28).rolling(180).mean())
    data['rolling_std_t30'] = data.groupby(['id'])['sold'].transform(lambda x: x.shift(28).rolling(30).std())
    data['rolling_skew_t30'] = data.groupby(['id'])['sold'].transform(lambda x: x.shift(28).rolling(30).skew())
    data['rolling_kurt_t30'] = data.groupby(['id'])['sold'].transform(lambda x: x.shift(28).rolling(30).kurt())
    return data

# %% [markdown]
# ### Price Features

# %%
def price_fe(data):
    # price features
    data['lag_price_t1'] = data.groupby(['id'])['sell_price'].transform(lambda x: x.shift(1))
    data['price_change_t1'] = (data['lag_price_t1'] - data['sell_price']) / (data['lag_price_t1'])
    data['rolling_price_max_t365'] = data.groupby(['id'])['sell_price'].transform(lambda x: x.shift(1).rolling(365).max())
    data['price_change_t365'] = (data['rolling_price_max_t365'] - data['sell_price']) / (data['rolling_price_max_t365'])
    data['rolling_price_std_t7'] = data.groupby(['id'])['sell_price'].transform(lambda x: x.rolling(7).std())
    data['rolling_price_std_t30'] = data.groupby(['id'])['sell_price'].transform(lambda x: x.rolling(30).std())
    data.drop(['rolling_price_max_t365', 'lag_price_t1'], inplace = True, axis = 1)
    return data

# %% [markdown]
# ## Data Preprocessing
# Get our dataset into a format the models will be able to use

# %%
df.isna().sum()
# Out:
# wm_yr_wk               0
# wday                   0
# month                  0
# year                   0
# event_name_1           0
# event_type_1           0
# event_name_2           0
# event_type_2           0
# snap_CA                0
# snap_TX                0
# snap_WI                0
# id                     0
# item_id                0
# dept_id                0
# cat_id                 0
# store_id               0
# state_id               0
# sold             1707440
# sell_price      12299413
# dtype: int64

# %%
df['sell_price'] = df['sell_price'].fillna(-1)

# %%
df['sold'] = df['sold'].fillna(0)

# %%
import numpy as np

df = demand_fe(df)
df = price_fe(df)

targets = df['2015-01-27':]['sold']
data = df['2015-01-27':].drop('sold', axis=1)
del df

numeric_columns = data.select_dtypes('number').columns
# data[numeric_columns] = ss.fit_transform(data[numeric_columns])
# gc.collect()

X_train = data[:'2016-03-27'].reset_index()
y_train = targets[:'2016-03-27']

X_val = data['2016-03-28':'2016-04-24'].reset_index()
y_val = targets['2016-03-28':'2016-04-24']

X_test_val = data['2016-04-25':'2016-05-22'].reset_index()
y_test_val = targets['2016-04-25':'2016-05-22']

X_test_eval = data['2016-05-23':].reset_index()
y_test_eval = targets['2016-05-23':]

del data
del targets

# %%
X_val.dtypes

# %%
X_train['date']
# Out:
# 0          2015-03-27
# 1          2015-03-27
# 2          2015-03-27
# 3          2015-03-27
# 4          2015-03-27
#               ...
# 11189825   2016-03-27
# 11189826   2016-03-27
# 11189827   2016-03-27
# 11189828   2016-03-27
# 11189829   2016-03-27
# Name: date, Length: 11189830, dtype: datetime64[ns]

# %%
X_val['date'].nunique()
# Out:
# 28

# %%
X_test_val['date'].nunique()
# Out:
# 28

# %%
X_test_eval['date'].nunique()
# Out:
# 28

# %%
X_test_eval['date'].nunique()
# Out:
# 28

# %%
import gc
gc.collect()
# Out:
# 821

# %% [markdown]
# ## NN Model
# Instantiate, create, and compile a basic Dense model for testing.

# %%
from keras.models import Sequential 
from keras import layers 
from keras.optimizers import RMSprop

def get_model():
    model = Sequential() 
    model.add(layers.Dense(512, activation='relu', input_shape=(X_train[numeric_columns].shape[1], )))  
    model.add(layers.Dense(75, activation='relu'))  
    model.add(layers.Dense(10, activation='relu'))  
    model.add(layers.Dense(1))
    model.compile(optimizer='rmsprop', loss='mse') 
    return model
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Example

# %%
y_train
# Out:
# date
# 2015-04-25    2
# 2015-04-25    0
# 2015-04-25    0
# 2015-04-25    2
# 2015-04-25    2
#              ..
# 2016-03-30    0
# 2016-03-30    0
# 2016-03-30    0
# 2016-03-30    0
# 2016-03-30    1
# Name: sold, Length: 10397090, dtype: int64

# %%
model = get_model()
history = model.fit(X_train[numeric_columns], 
                    y_train, 
                    # batch_size=10000,
                    # shuffle=True,
                    # steps_per_epoch=len(y_train)//2000,
                    epochs=2, 
                    validation_data=(X_val[numeric_columns], y_val),
                    # validation_steps=len(y_test)//200
                    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-7049b6476055> in <module>()
# ----> 1 model = get_model()
#       2 history = model.fit(X_train[numeric_columns],
#       3                     y_train,
#       4                     # batch_size=10000,
#       5                     # shuffle=True,
#
# NameError: name 'get_model' is not defined

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %% [markdown]
# ## LGBM Model
# The NN model is not fitting to our data.
#
# We will try a LGBM model and see if it has better luck

# %%
import lightgbm as lgbm

# %%
train_lgbm = lgbm.Dataset(X_train[numeric_columns], y_train)
val_lgbm = lgbm.Dataset(X_val[numeric_columns], y_val)

# %%
X_train.shape
# Out:
# (12988740, 34)

# %%
y_train.shape
# Out:
# (12988740,)

# %%
params = {'metrics': 'rmse', 'colsample_bytree': 0.6761597976790243, 'min_child_samples': 281, 'min_child_weight': 100.0, 'num_leaves': 11, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.2970194609775752}

# %% [markdown]
# ### Example

# %%
from sklearn import metrics
model = lgbm.train(params, 
                   train_lgbm, 
                   num_boost_round = 2500, 
                   early_stopping_rounds = 50, 
                   valid_sets = [train_lgbm, val_lgbm], 
                   verbose_eval = 100)

val_pred = model.predict(X_val[numeric_columns])
val_score = np.sqrt(metrics.mean_squared_error(val_pred, y_val))
print(f'Our val rmse score is {val_score}')
# Out:
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 2.27706	valid_1's rmse: 2.14778
# [200]	training's rmse: 2.23974	valid_1's rmse: 2.1326
# Early stopping, best iteration is:
# [196]	training's rmse: 2.24115	valid_1's rmse: 2.13234
# Our val rmse score is 2.1323399083331336

# %%
224,213
219,213
218, 216

# %% [markdown]
# ### Hyperparam Tuning

# %%
from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform
param_test ={'num_leaves': sp_randint(6, 50), 
             'min_child_samples': sp_randint(100, 500), 
             'min_child_weight': [1e-5, 1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3, 1e4],
             'subsample': sp_uniform(loc=0.2, scale=0.8), 
             'colsample_bytree': sp_uniform(loc=0.4, scale=0.6),
             'reg_alpha': [0, 1e-1, 1, 2, 5, 7, 10, 50, 100],
             'reg_lambda': [0, 1e-1, 1, 5, 10, 20, 50, 100]}

# %%
#This parameter defines the number of HP points to be tested
n_HP_points_to_test = 100

# %%
clf = lgbm.LGBMRegressor(max_depth=-1,
                         random_state=236, 
                         silent=True, 
                         metric='rmse', 
                         n_jobs=-1, 
                         n_estimators=5000)

# %%
from sklearn.model_selection import RandomizedSearchCV
gs = RandomizedSearchCV(
    estimator=clf, 
    param_distributions=param_test, 
    n_iter=n_HP_points_to_test,
    scoring='neg_root_mean_squared_error',
    cv=3,
    refit=True,
    random_state=236,
    verbose=True)

# %%
fit_params={"early_stopping_rounds":50, 
            "eval_metric" : 'rmse', 
            "eval_set" : [(val_lgbm.data, val_lgbm.label)],
            'eval_names': ['valid'],
            #'callbacks': [lgb.reset_parameter(learning_rate=learning_rate_010_decay_power_099)],
            'verbose': 100,
            'categorical_feature': 'auto'}

# %%
gs.fit(train_lgbm.data, train_lgbm.label, **fit_params)
print('Best score reached: {} with params: {} '.format(gs.best_score_, gs.best_params_))
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15669
# [200]	valid's rmse: 2.15106
# Early stopping, best iteration is:
# [228]	valid's rmse: 2.14987
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13549
# [200]	valid's rmse: 2.12408
# [300]	valid's rmse: 2.12298
# Early stopping, best iteration is:
# [269]	valid's rmse: 2.1217
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.1639
# [200]	valid's rmse: 2.15998
# Early stopping, best iteration is:
# [155]	valid's rmse: 2.15892
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.1593
# [200]	valid's rmse: 2.16429
# Early stopping, best iteration is:
# [165]	valid's rmse: 2.1552
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.12498
# [200]	valid's rmse: 2.11896
# Early stopping, best iteration is:
# [189]	valid's rmse: 2.11773
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16163
# Early stopping, best iteration is:
# [117]	valid's rmse: 2.15966
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15674
# Early stopping, best iteration is:
# [100]	valid's rmse: 2.15674
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.12702
# Early stopping, best iteration is:
# [127]	valid's rmse: 2.12442
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16432
# Early stopping, best iteration is:
# [124]	valid's rmse: 2.16142
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15764
# [200]	valid's rmse: 2.15568
# Early stopping, best iteration is:
# [173]	valid's rmse: 2.15429
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.12749
# [200]	valid's rmse: 2.12505
# Early stopping, best iteration is:
# [182]	valid's rmse: 2.12104
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15583
# [200]	valid's rmse: 2.15412
# Early stopping, best iteration is:
# [181]	valid's rmse: 2.15253
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.21989
# [200]	valid's rmse: 2.21357
# [300]	valid's rmse: 2.20831
# [400]	valid's rmse: 2.20649
# [500]	valid's rmse: 2.20542
# [600]	valid's rmse: 2.20309
# [700]	valid's rmse: 2.20218
# Early stopping, best iteration is:
# [723]	valid's rmse: 2.20168
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.19576
# [200]	valid's rmse: 2.18035
# [300]	valid's rmse: 2.17525
# [400]	valid's rmse: 2.17136
# [500]	valid's rmse: 2.16938
# [600]	valid's rmse: 2.16861
# Early stopping, best iteration is:
# [586]	valid's rmse: 2.16835
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.20584
# [200]	valid's rmse: 2.19793
# [300]	valid's rmse: 2.19596
# [400]	valid's rmse: 2.19283
# Early stopping, best iteration is:
# [440]	valid's rmse: 2.19161
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16981
# [200]	valid's rmse: 2.16066
# [300]	valid's rmse: 2.16045
# Early stopping, best iteration is:
# [262]	valid's rmse: 2.15719
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15233
# [200]	valid's rmse: 2.13936
# [300]	valid's rmse: 2.13159
# [400]	valid's rmse: 2.12639
# Early stopping, best iteration is:
# [401]	valid's rmse: 2.12638
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16619
# [200]	valid's rmse: 2.15734
# Early stopping, best iteration is:
# [232]	valid's rmse: 2.15675
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15618
# [200]	valid's rmse: 2.1513
# Early stopping, best iteration is:
# [189]	valid's rmse: 2.14628
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.135
# [200]	valid's rmse: 2.1299
# [300]	valid's rmse: 2.12981
# Early stopping, best iteration is:
# [253]	valid's rmse: 2.12801
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16624
# [200]	valid's rmse: 2.16186
# Early stopping, best iteration is:
# [188]	valid's rmse: 2.15963
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16283
# [200]	valid's rmse: 2.15615
# [300]	valid's rmse: 2.15388
# [400]	valid's rmse: 2.1537
# Early stopping, best iteration is:
# [354]	valid's rmse: 2.15318
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.14441
# [200]	valid's rmse: 2.13613
# [300]	valid's rmse: 2.12836
# [400]	valid's rmse: 2.12492
# Early stopping, best iteration is:
# [398]	valid's rmse: 2.12442
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16936
# [200]	valid's rmse: 2.16263
# [300]	valid's rmse: 2.15909
# Early stopping, best iteration is:
# [301]	valid's rmse: 2.15884
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16037
# [200]	valid's rmse: 2.15552
# Early stopping, best iteration is:
# [151]	valid's rmse: 2.15344
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13985
# [200]	valid's rmse: 2.12798
# Early stopping, best iteration is:
# [239]	valid's rmse: 2.12702
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16395
# [200]	valid's rmse: 2.1574
# Early stopping, best iteration is:
# [233]	valid's rmse: 2.15548
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.1603
# Early stopping, best iteration is:
# [127]	valid's rmse: 2.15785
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13799
# [200]	valid's rmse: 2.13136
# Early stopping, best iteration is:
# [179]	valid's rmse: 2.13069
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16366
# Early stopping, best iteration is:
# [106]	valid's rmse: 2.16248
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15895
# [200]	valid's rmse: 2.15358
# Early stopping, best iteration is:
# [184]	valid's rmse: 2.15265
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13207
# [200]	valid's rmse: 2.12524
# [300]	valid's rmse: 2.12443
# Early stopping, best iteration is:
# [277]	valid's rmse: 2.12263
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16365
# Early stopping, best iteration is:
# [146]	valid's rmse: 2.16025
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16668
# [200]	valid's rmse: 2.16168
# Early stopping, best iteration is:
# [172]	valid's rmse: 2.1574
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15071
# [200]	valid's rmse: 2.14147
# [300]	valid's rmse: 2.13469
# [400]	valid's rmse: 2.12841
# Early stopping, best iteration is:
# [406]	valid's rmse: 2.12821
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.17043
# [200]	valid's rmse: 2.15889
# [300]	valid's rmse: 2.15513
# Early stopping, best iteration is:
# [317]	valid's rmse: 2.15419
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15561
# Early stopping, best iteration is:
# [118]	valid's rmse: 2.15091
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.12399
# Early stopping, best iteration is:
# [138]	valid's rmse: 2.12158
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15827
# Early stopping, best iteration is:
# [112]	valid's rmse: 2.15497
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15506
# [200]	valid's rmse: 2.15106
# Early stopping, best iteration is:
# [167]	valid's rmse: 2.1497
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13252
# [200]	valid's rmse: 2.13192
# Early stopping, best iteration is:
# [187]	valid's rmse: 2.12683
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16639
# [200]	valid's rmse: 2.16873
# Early stopping, best iteration is:
# [168]	valid's rmse: 2.1627
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15868
# Early stopping, best iteration is:
# [64]	valid's rmse: 2.15549
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.12758
# Early stopping, best iteration is:
# [117]	valid's rmse: 2.12563
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16204
# Early stopping, best iteration is:
# [122]	valid's rmse: 2.15998
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.1587
# [200]	valid's rmse: 2.15329
# Early stopping, best iteration is:
# [202]	valid's rmse: 2.15284
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.14153
# [200]	valid's rmse: 2.12934
# [300]	valid's rmse: 2.12497
# Early stopping, best iteration is:
# [338]	valid's rmse: 2.12313
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.1673
# [200]	valid's rmse: 2.15786
# Early stopping, best iteration is:
# [241]	valid's rmse: 2.15736
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.17261
# [200]	valid's rmse: 2.1594
# Early stopping, best iteration is:
# [221]	valid's rmse: 2.15701
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15501
# [200]	valid's rmse: 2.13885
# [300]	valid's rmse: 2.13168
# [400]	valid's rmse: 2.12889
# [500]	valid's rmse: 2.12915
# Early stopping, best iteration is:
# [463]	valid's rmse: 2.12758
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.1724
# [200]	valid's rmse: 2.16098
# Early stopping, best iteration is:
# [241]	valid's rmse: 2.15927
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16267
# [200]	valid's rmse: 2.1671
# Early stopping, best iteration is:
# [164]	valid's rmse: 2.15923
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13695
# [200]	valid's rmse: 2.13146
# Early stopping, best iteration is:
# [207]	valid's rmse: 2.1311
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15907
# [200]	valid's rmse: 2.15224
# Early stopping, best iteration is:
# [227]	valid's rmse: 2.15136
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.17055
# [200]	valid's rmse: 2.16333
# [300]	valid's rmse: 2.15944
# [400]	valid's rmse: 2.15752
# Early stopping, best iteration is:
# [352]	valid's rmse: 2.15716
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.1608
# [200]	valid's rmse: 2.14737
# [300]	valid's rmse: 2.14156
# [400]	valid's rmse: 2.13569
# [500]	valid's rmse: 2.13352
# Early stopping, best iteration is:
# [517]	valid's rmse: 2.13258
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.17479
# [200]	valid's rmse: 2.16868
# [300]	valid's rmse: 2.16435
# Early stopping, best iteration is:
# [298]	valid's rmse: 2.16393
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16169
# Early stopping, best iteration is:
# [148]	valid's rmse: 2.15525
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13981
# [200]	valid's rmse: 2.12758
# Early stopping, best iteration is:
# [231]	valid's rmse: 2.12486
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16941
# [200]	valid's rmse: 2.16299
# Early stopping, best iteration is:
# [160]	valid's rmse: 2.15965
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15476
# [200]	valid's rmse: 2.14878
# Early stopping, best iteration is:
# [197]	valid's rmse: 2.14789
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13763
# [200]	valid's rmse: 2.1307
# [300]	valid's rmse: 2.1303
# Early stopping, best iteration is:
# [263]	valid's rmse: 2.12796
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16595
# [200]	valid's rmse: 2.16633
# Early stopping, best iteration is:
# [167]	valid's rmse: 2.16001
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15724
# [200]	valid's rmse: 2.15494
# Early stopping, best iteration is:
# [155]	valid's rmse: 2.15344
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.12652
# [200]	valid's rmse: 2.12518
# Early stopping, best iteration is:
# [169]	valid's rmse: 2.12297
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.1589
# Early stopping, best iteration is:
# [115]	valid's rmse: 2.15767
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15621
# Early stopping, best iteration is:
# [128]	valid's rmse: 2.1513
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.12614
# [200]	valid's rmse: 2.12806
# Early stopping, best iteration is:
# [165]	valid's rmse: 2.12354
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.17105
# Early stopping, best iteration is:
# [128]	valid's rmse: 2.16936
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15862
# [200]	valid's rmse: 2.15777
# Early stopping, best iteration is:
# [158]	valid's rmse: 2.15244
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.12132
# [200]	valid's rmse: 2.13013
# Early stopping, best iteration is:
# [153]	valid's rmse: 2.11892
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15512
# Early stopping, best iteration is:
# [137]	valid's rmse: 2.15106
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.2192
# [200]	valid's rmse: 2.21284
# [300]	valid's rmse: 2.20948
# [400]	valid's rmse: 2.20764
# [500]	valid's rmse: 2.20638
# [600]	valid's rmse: 2.20532
# Early stopping, best iteration is:
# [563]	valid's rmse: 2.20491
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.19329
# [200]	valid's rmse: 2.17908
# [300]	valid's rmse: 2.17464
# [400]	valid's rmse: 2.17248
# [500]	valid's rmse: 2.17157
# [600]	valid's rmse: 2.17056
# Early stopping, best iteration is:
# [605]	valid's rmse: 2.17035
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.20389
# [200]	valid's rmse: 2.19689
# Early stopping, best iteration is:
# [249]	valid's rmse: 2.19415
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15919
# Early stopping, best iteration is:
# [105]	valid's rmse: 2.15841
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13207
# Early stopping, best iteration is:
# [133]	valid's rmse: 2.13111
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16655
# Early stopping, best iteration is:
# [114]	valid's rmse: 2.16492
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15893
# Early stopping, best iteration is:
# [140]	valid's rmse: 2.15627
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.12824
# [200]	valid's rmse: 2.12435
# Early stopping, best iteration is:
# [188]	valid's rmse: 2.1232
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15838
# [200]	valid's rmse: 2.15423
# Early stopping, best iteration is:
# [192]	valid's rmse: 2.15247
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15284
# [200]	valid's rmse: 2.15022
# Early stopping, best iteration is:
# [176]	valid's rmse: 2.14706
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.12396
# [200]	valid's rmse: 2.12432
# Early stopping, best iteration is:
# [191]	valid's rmse: 2.12162
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.17156
# Early stopping, best iteration is:
# [73]	valid's rmse: 2.16958
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15185
# Early stopping, best iteration is:
# [133]	valid's rmse: 2.14811
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.12521
# Early stopping, best iteration is:
# [138]	valid's rmse: 2.11887
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15574
# Early stopping, best iteration is:
# [110]	valid's rmse: 2.15517
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15812
# [200]	valid's rmse: 2.15484
# Early stopping, best iteration is:
# [176]	valid's rmse: 2.15175
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13462
# [200]	valid's rmse: 2.12625
# Early stopping, best iteration is:
# [241]	valid's rmse: 2.12446
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16122
# Early stopping, best iteration is:
# [138]	valid's rmse: 2.15748
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15037
# Early stopping, best iteration is:
# [114]	valid's rmse: 2.14885
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.12457
# Early stopping, best iteration is:
# [107]	valid's rmse: 2.12338
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16682
# Early stopping, best iteration is:
# [106]	valid's rmse: 2.16581
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.22069
# [200]	valid's rmse: 2.21525
# [300]	valid's rmse: 2.20946
# [400]	valid's rmse: 2.20744
# Early stopping, best iteration is:
# [387]	valid's rmse: 2.20699
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.20216
# [200]	valid's rmse: 2.18678
# [300]	valid's rmse: 2.17852
# [400]	valid's rmse: 2.17491
# [500]	valid's rmse: 2.17227
# [600]	valid's rmse: 2.17038
# [700]	valid's rmse: 2.16959
# [800]	valid's rmse: 2.16923
# Early stopping, best iteration is:
# [780]	valid's rmse: 2.16888
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.20762
# [200]	valid's rmse: 2.1993
# [300]	valid's rmse: 2.19533
# [400]	valid's rmse: 2.1924
# Early stopping, best iteration is:
# [431]	valid's rmse: 2.19123
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15805
# [200]	valid's rmse: 2.15156
# Early stopping, best iteration is:
# [214]	valid's rmse: 2.15137
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.1342
# [200]	valid's rmse: 2.12377
# [300]	valid's rmse: 2.12166
# [400]	valid's rmse: 2.12677
# Early stopping, best iteration is:
# [362]	valid's rmse: 2.12079
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16247
# [200]	valid's rmse: 2.15971
# Early stopping, best iteration is:
# [154]	valid's rmse: 2.15865
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.1655
# [200]	valid's rmse: 2.15499
# Early stopping, best iteration is:
# [201]	valid's rmse: 2.15491
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.14323
# [200]	valid's rmse: 2.13172
# [300]	valid's rmse: 2.1311
# Early stopping, best iteration is:
# [265]	valid's rmse: 2.12689
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16475
# Early stopping, best iteration is:
# [140]	valid's rmse: 2.15858
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15932
# Early stopping, best iteration is:
# [132]	valid's rmse: 2.15876
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13007
# [200]	valid's rmse: 2.12813
# Early stopping, best iteration is:
# [206]	valid's rmse: 2.12713
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16347
# Early stopping, best iteration is:
# [86]	valid's rmse: 2.16276
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15808
# Early stopping, best iteration is:
# [134]	valid's rmse: 2.15364
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.12716
# [200]	valid's rmse: 2.12577
# Early stopping, best iteration is:
# [162]	valid's rmse: 2.12374
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15707
# [200]	valid's rmse: 2.15341
# Early stopping, best iteration is:
# [196]	valid's rmse: 2.15239
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16419
# [200]	valid's rmse: 2.15247
# [300]	valid's rmse: 2.15012
# Early stopping, best iteration is:
# [288]	valid's rmse: 2.14987
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.1485
# [200]	valid's rmse: 2.13449
# [300]	valid's rmse: 2.13159
# [400]	valid's rmse: 2.13069
# Early stopping, best iteration is:
# [373]	valid's rmse: 2.12843
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16819
# [200]	valid's rmse: 2.15795
# Early stopping, best iteration is:
# [197]	valid's rmse: 2.15723
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.1626
# Early stopping, best iteration is:
# [128]	valid's rmse: 2.16011
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.12585
# [200]	valid's rmse: 2.12283
# Early stopping, best iteration is:
# [166]	valid's rmse: 2.11841
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.17083
# Early stopping, best iteration is:
# [138]	valid's rmse: 2.1675
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16819
# [200]	valid's rmse: 2.15798
# Early stopping, best iteration is:
# [216]	valid's rmse: 2.15743
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15331
# [200]	valid's rmse: 2.13937
# [300]	valid's rmse: 2.13145
# [400]	valid's rmse: 2.12809
# Early stopping, best iteration is:
# [413]	valid's rmse: 2.12744
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16886
# [200]	valid's rmse: 2.15873
# Early stopping, best iteration is:
# [241]	valid's rmse: 2.15776
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15239
# Early stopping, best iteration is:
# [107]	valid's rmse: 2.15202
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.12831
# [200]	valid's rmse: 2.12577
# Early stopping, best iteration is:
# [166]	valid's rmse: 2.12383
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16116
# Early stopping, best iteration is:
# [124]	valid's rmse: 2.1599
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15654
# Early stopping, best iteration is:
# [134]	valid's rmse: 2.15332
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.12786
# Early stopping, best iteration is:
# [132]	valid's rmse: 2.12439
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16229
# Early stopping, best iteration is:
# [147]	valid's rmse: 2.15808
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15527
# Early stopping, best iteration is:
# [121]	valid's rmse: 2.15281
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.12264
# Early stopping, best iteration is:
# [130]	valid's rmse: 2.11941
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15845
# Early stopping, best iteration is:
# [123]	valid's rmse: 2.15616
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15794
# [200]	valid's rmse: 2.15913
# Early stopping, best iteration is:
# [151]	valid's rmse: 2.15441
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.12534
# [200]	valid's rmse: 2.13013
# Early stopping, best iteration is:
# [167]	valid's rmse: 2.12018
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15181
# Early stopping, best iteration is:
# [99]	valid's rmse: 2.15062
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16529
# Early stopping, best iteration is:
# [145]	valid's rmse: 2.16338
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13673
# [200]	valid's rmse: 2.13162
# [300]	valid's rmse: 2.12796
# [400]	valid's rmse: 2.12639
# Early stopping, best iteration is:
# [400]	valid's rmse: 2.12639
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.1655
# [200]	valid's rmse: 2.16398
# Early stopping, best iteration is:
# [189]	valid's rmse: 2.16259
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15673
# Early stopping, best iteration is:
# [117]	valid's rmse: 2.1527
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13366
# [200]	valid's rmse: 2.12757
# Early stopping, best iteration is:
# [167]	valid's rmse: 2.12689
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16147
# [200]	valid's rmse: 2.15632
# Early stopping, best iteration is:
# [171]	valid's rmse: 2.15214
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16159
# [200]	valid's rmse: 2.15645
# [300]	valid's rmse: 2.15421
# Early stopping, best iteration is:
# [278]	valid's rmse: 2.15274
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13802
# [200]	valid's rmse: 2.12755
# [300]	valid's rmse: 2.12709
# Early stopping, best iteration is:
# [264]	valid's rmse: 2.12426
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16629
# [200]	valid's rmse: 2.16257
# Early stopping, best iteration is:
# [156]	valid's rmse: 2.15992
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15597
# Early stopping, best iteration is:
# [119]	valid's rmse: 2.15341
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.12579
# [200]	valid's rmse: 2.13521
# Early stopping, best iteration is:
# [153]	valid's rmse: 2.12153
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16498
# Early stopping, best iteration is:
# [87]	valid's rmse: 2.1638
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.21955
# [200]	valid's rmse: 2.2143
# [300]	valid's rmse: 2.20813
# [400]	valid's rmse: 2.20605
# [500]	valid's rmse: 2.20521
# [600]	valid's rmse: 2.20403
# Early stopping, best iteration is:
# [628]	valid's rmse: 2.20325
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.20069
# [200]	valid's rmse: 2.18396
# [300]	valid's rmse: 2.17866
# [400]	valid's rmse: 2.17452
# [500]	valid's rmse: 2.17203
# Early stopping, best iteration is:
# [541]	valid's rmse: 2.17087
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.2086
# [200]	valid's rmse: 2.20106
# [300]	valid's rmse: 2.1972
# Early stopping, best iteration is:
# [308]	valid's rmse: 2.19713
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16082
# Early stopping, best iteration is:
# [119]	valid's rmse: 2.15858
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13178
# Early stopping, best iteration is:
# [96]	valid's rmse: 2.13103
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16726
# Early stopping, best iteration is:
# [64]	valid's rmse: 2.1665
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.22245
# [200]	valid's rmse: 2.21514
# [300]	valid's rmse: 2.21171
# [400]	valid's rmse: 2.21014
# [500]	valid's rmse: 2.2081
# [600]	valid's rmse: 2.20693
# [700]	valid's rmse: 2.20567
# Early stopping, best iteration is:
# [683]	valid's rmse: 2.20547
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.19788
# [200]	valid's rmse: 2.18423
# [300]	valid's rmse: 2.1774
# [400]	valid's rmse: 2.1723
# [500]	valid's rmse: 2.16922
# [600]	valid's rmse: 2.16787
# [700]	valid's rmse: 2.16708
# Early stopping, best iteration is:
# [735]	valid's rmse: 2.16637
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.20615
# [200]	valid's rmse: 2.19702
# [300]	valid's rmse: 2.19236
# [400]	valid's rmse: 2.19003
# Early stopping, best iteration is:
# [399]	valid's rmse: 2.19
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16613
# [200]	valid's rmse: 2.15742
# [300]	valid's rmse: 2.15669
# Early stopping, best iteration is:
# [267]	valid's rmse: 2.15186
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13813
# [200]	valid's rmse: 2.12885
# [300]	valid's rmse: 2.12127
# Early stopping, best iteration is:
# [308]	valid's rmse: 2.121
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16702
# [200]	valid's rmse: 2.16399
# Early stopping, best iteration is:
# [155]	valid's rmse: 2.16015
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15386
# [200]	valid's rmse: 2.15351
# Early stopping, best iteration is:
# [188]	valid's rmse: 2.15144
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.1313
# [200]	valid's rmse: 2.12639
# Early stopping, best iteration is:
# [249]	valid's rmse: 2.12357
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16719
# [200]	valid's rmse: 2.16033
# Early stopping, best iteration is:
# [198]	valid's rmse: 2.16021
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15787
# Early stopping, best iteration is:
# [117]	valid's rmse: 2.15591
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.12698
# [200]	valid's rmse: 2.12964
# Early stopping, best iteration is:
# [150]	valid's rmse: 2.12414
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16187
# [200]	valid's rmse: 2.16491
# Early stopping, best iteration is:
# [151]	valid's rmse: 2.15717
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15803
# Early stopping, best iteration is:
# [62]	valid's rmse: 2.15375
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.12027
# Early stopping, best iteration is:
# [128]	valid's rmse: 2.11771
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [39]	valid's rmse: 2.16417
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.1565
# Early stopping, best iteration is:
# [137]	valid's rmse: 2.15456
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13323
# [200]	valid's rmse: 2.12718
# Early stopping, best iteration is:
# [190]	valid's rmse: 2.12541
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16636
# [200]	valid's rmse: 2.16557
# Early stopping, best iteration is:
# [162]	valid's rmse: 2.16385
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15818
# [200]	valid's rmse: 2.15426
# Early stopping, best iteration is:
# [195]	valid's rmse: 2.15282
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13317
# Early stopping, best iteration is:
# [142]	valid's rmse: 2.12842
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16269
# Early stopping, best iteration is:
# [138]	valid's rmse: 2.16149
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16523
# [200]	valid's rmse: 2.15535
# Early stopping, best iteration is:
# [223]	valid's rmse: 2.15457
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.14053
# [200]	valid's rmse: 2.13294
# [300]	valid's rmse: 2.12573
# [400]	valid's rmse: 2.12515
# Early stopping, best iteration is:
# [369]	valid's rmse: 2.12392
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.1703
# [200]	valid's rmse: 2.15947
# Early stopping, best iteration is:
# [233]	valid's rmse: 2.15696
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16371
# [200]	valid's rmse: 2.15881
# Early stopping, best iteration is:
# [205]	valid's rmse: 2.15831
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.14615
# [200]	valid's rmse: 2.13675
# [300]	valid's rmse: 2.13112
# Early stopping, best iteration is:
# [283]	valid's rmse: 2.13101
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16562
# [200]	valid's rmse: 2.15497
# Early stopping, best iteration is:
# [199]	valid's rmse: 2.15482
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16178
# Early stopping, best iteration is:
# [134]	valid's rmse: 2.15966
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.12963
# [200]	valid's rmse: 2.12596
# Early stopping, best iteration is:
# [159]	valid's rmse: 2.12441
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16034
# [200]	valid's rmse: 2.15649
# Early stopping, best iteration is:
# [166]	valid's rmse: 2.15481
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.22117
# [200]	valid's rmse: 2.21293
# [300]	valid's rmse: 2.20813
# [400]	valid's rmse: 2.20527
# [500]	valid's rmse: 2.20326
# Early stopping, best iteration is:
# [494]	valid's rmse: 2.20274
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.1964
# [200]	valid's rmse: 2.18442
# [300]	valid's rmse: 2.17796
# [400]	valid's rmse: 2.17361
# [500]	valid's rmse: 2.1716
# [600]	valid's rmse: 2.16952
# [700]	valid's rmse: 2.16814
# [800]	valid's rmse: 2.1675
# [900]	valid's rmse: 2.16681
# Early stopping, best iteration is:
# [851]	valid's rmse: 2.16661
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.20861
# [200]	valid's rmse: 2.19904
# [300]	valid's rmse: 2.1946
# [400]	valid's rmse: 2.19332
# Early stopping, best iteration is:
# [378]	valid's rmse: 2.1925
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16276
# [200]	valid's rmse: 2.16083
# [300]	valid's rmse: 2.15683
# Early stopping, best iteration is:
# [339]	valid's rmse: 2.15621
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.14948
# [200]	valid's rmse: 2.13653
# [300]	valid's rmse: 2.12887
# [400]	valid's rmse: 2.12716
# Early stopping, best iteration is:
# [434]	valid's rmse: 2.12609
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16399
# [200]	valid's rmse: 2.15893
# [300]	valid's rmse: 2.15931
# Early stopping, best iteration is:
# [281]	valid's rmse: 2.15695
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16005
# [200]	valid's rmse: 2.15717
# Early stopping, best iteration is:
# [186]	valid's rmse: 2.15693
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.14419
# [200]	valid's rmse: 2.1341
# [300]	valid's rmse: 2.13108
# Early stopping, best iteration is:
# [309]	valid's rmse: 2.12963
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16087
# [200]	valid's rmse: 2.1559
# Early stopping, best iteration is:
# [214]	valid's rmse: 2.15398
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16725
# [200]	valid's rmse: 2.15974
# Early stopping, best iteration is:
# [228]	valid's rmse: 2.15681
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15156
# [200]	valid's rmse: 2.13778
# [300]	valid's rmse: 2.13509
# Early stopping, best iteration is:
# [303]	valid's rmse: 2.1347
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16901
# [200]	valid's rmse: 2.15562
# Early stopping, best iteration is:
# [226]	valid's rmse: 2.15173
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15456
# Early stopping, best iteration is:
# [87]	valid's rmse: 2.15294
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.11992
# Early stopping, best iteration is:
# [108]	valid's rmse: 2.11862
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15743
# Early stopping, best iteration is:
# [135]	valid's rmse: 2.15619
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.14964
# Early stopping, best iteration is:
# [109]	valid's rmse: 2.14921
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.12665
# Early stopping, best iteration is:
# [120]	valid's rmse: 2.12467
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16526
# Early stopping, best iteration is:
# [132]	valid's rmse: 2.15997
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.22045
# [200]	valid's rmse: 2.2145
# [300]	valid's rmse: 2.21106
# [400]	valid's rmse: 2.20936
# [500]	valid's rmse: 2.20903
# Early stopping, best iteration is:
# [451]	valid's rmse: 2.20877
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.19423
# [200]	valid's rmse: 2.18056
# [300]	valid's rmse: 2.17504
# [400]	valid's rmse: 2.17357
# [500]	valid's rmse: 2.17283
# Early stopping, best iteration is:
# [517]	valid's rmse: 2.17248
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.20423
# [200]	valid's rmse: 2.19565
# [300]	valid's rmse: 2.19451
# Early stopping, best iteration is:
# [314]	valid's rmse: 2.19336
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.1538
# Early stopping, best iteration is:
# [149]	valid's rmse: 2.1516
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.12806
# Early stopping, best iteration is:
# [110]	valid's rmse: 2.12548
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16614
# Early stopping, best iteration is:
# [132]	valid's rmse: 2.16496
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15687
# Early stopping, best iteration is:
# [117]	valid's rmse: 2.15443
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.11996
# Early stopping, best iteration is:
# [107]	valid's rmse: 2.11859
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.1584
# Early stopping, best iteration is:
# [95]	valid's rmse: 2.1583
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.1686
# [200]	valid's rmse: 2.16297
# [300]	valid's rmse: 2.15638
# [400]	valid's rmse: 2.15398
# Early stopping, best iteration is:
# [411]	valid's rmse: 2.15338
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15804
# [200]	valid's rmse: 2.14505
# [300]	valid's rmse: 2.13866
# [400]	valid's rmse: 2.13571
# Early stopping, best iteration is:
# [449]	valid's rmse: 2.13313
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16614
# [200]	valid's rmse: 2.15889
# [300]	valid's rmse: 2.15539
# Early stopping, best iteration is:
# [300]	valid's rmse: 2.15539
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15499
# Early stopping, best iteration is:
# [137]	valid's rmse: 2.15165
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13277
# [200]	valid's rmse: 2.13356
# Early stopping, best iteration is:
# [156]	valid's rmse: 2.12945
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16065
# Early stopping, best iteration is:
# [135]	valid's rmse: 2.15644
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.22091
# [200]	valid's rmse: 2.21223
# [300]	valid's rmse: 2.2082
# [400]	valid's rmse: 2.20766
# [500]	valid's rmse: 2.206
# [600]	valid's rmse: 2.2049
# Early stopping, best iteration is:
# [641]	valid's rmse: 2.2045
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.20034
# [200]	valid's rmse: 2.1839
# [300]	valid's rmse: 2.17634
# [400]	valid's rmse: 2.17288
# [500]	valid's rmse: 2.17055
# [600]	valid's rmse: 2.16999
# Early stopping, best iteration is:
# [586]	valid's rmse: 2.16941
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.20845
# [200]	valid's rmse: 2.20088
# [300]	valid's rmse: 2.19513
# Early stopping, best iteration is:
# [312]	valid's rmse: 2.19396
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.1688
# [200]	valid's rmse: 2.16175
# [300]	valid's rmse: 2.15605
# Early stopping, best iteration is:
# [302]	valid's rmse: 2.156
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.14829
# [200]	valid's rmse: 2.13753
# Early stopping, best iteration is:
# [230]	valid's rmse: 2.13486
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.17283
# [200]	valid's rmse: 2.16508
# [300]	valid's rmse: 2.16223
# Early stopping, best iteration is:
# [274]	valid's rmse: 2.16112
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.21974
# [200]	valid's rmse: 2.21332
# [300]	valid's rmse: 2.20832
# [400]	valid's rmse: 2.2057
# [500]	valid's rmse: 2.20382
# [600]	valid's rmse: 2.20296
# [700]	valid's rmse: 2.20292
# Early stopping, best iteration is:
# [672]	valid's rmse: 2.20206
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.20307
# [200]	valid's rmse: 2.18682
# [300]	valid's rmse: 2.17961
# [400]	valid's rmse: 2.17484
# [500]	valid's rmse: 2.1718
# [600]	valid's rmse: 2.16941
# [700]	valid's rmse: 2.1685
# Early stopping, best iteration is:
# [650]	valid's rmse: 2.1684
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.20709
# [200]	valid's rmse: 2.19876
# [300]	valid's rmse: 2.1967
# Early stopping, best iteration is:
# [264]	valid's rmse: 2.1955
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15552
# [200]	valid's rmse: 2.15296
# Early stopping, best iteration is:
# [160]	valid's rmse: 2.14982
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13132
# Early stopping, best iteration is:
# [129]	valid's rmse: 2.1268
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15991
# [200]	valid's rmse: 2.16213
# Early stopping, best iteration is:
# [179]	valid's rmse: 2.15755
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15667
# Early stopping, best iteration is:
# [112]	valid's rmse: 2.15506
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13337
# [200]	valid's rmse: 2.12898
# Early stopping, best iteration is:
# [228]	valid's rmse: 2.12774
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15794
# Early stopping, best iteration is:
# [81]	valid's rmse: 2.15707
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.159
# Early stopping, best iteration is:
# [94]	valid's rmse: 2.15895
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13462
# Early stopping, best iteration is:
# [144]	valid's rmse: 2.13261
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16315
# Early stopping, best iteration is:
# [86]	valid's rmse: 2.16128
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.21999
# [200]	valid's rmse: 2.21432
# [300]	valid's rmse: 2.21018
# Early stopping, best iteration is:
# [316]	valid's rmse: 2.20945
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.19087
# [200]	valid's rmse: 2.17593
# [300]	valid's rmse: 2.17276
# [400]	valid's rmse: 2.17092
# [500]	valid's rmse: 2.16993
# [600]	valid's rmse: 2.16846
# Early stopping, best iteration is:
# [608]	valid's rmse: 2.16774
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.20549
# [200]	valid's rmse: 2.19852
# Early stopping, best iteration is:
# [227]	valid's rmse: 2.19838
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16445
# [200]	valid's rmse: 2.15627
# Early stopping, best iteration is:
# [236]	valid's rmse: 2.15475
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.14231
# [200]	valid's rmse: 2.13402
# [300]	valid's rmse: 2.12842
# [400]	valid's rmse: 2.12808
# Early stopping, best iteration is:
# [372]	valid's rmse: 2.12655
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16484
# [200]	valid's rmse: 2.16042
# [300]	valid's rmse: 2.15756
# Early stopping, best iteration is:
# [265]	valid's rmse: 2.15589
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.21812
# [200]	valid's rmse: 2.21322
# [300]	valid's rmse: 2.2097
# [400]	valid's rmse: 2.20717
# [500]	valid's rmse: 2.2064
# [600]	valid's rmse: 2.20419
# [700]	valid's rmse: 2.20321
# Early stopping, best iteration is:
# [691]	valid's rmse: 2.20287
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.19482
# [200]	valid's rmse: 2.17885
# [300]	valid's rmse: 2.17272
# [400]	valid's rmse: 2.17022
# [500]	valid's rmse: 2.16868
# Early stopping, best iteration is:
# [489]	valid's rmse: 2.16852
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.2037
# [200]	valid's rmse: 2.19715
# [300]	valid's rmse: 2.19396
# [400]	valid's rmse: 2.19149
# Early stopping, best iteration is:
# [424]	valid's rmse: 2.19095
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15558
# [200]	valid's rmse: 2.15653
# Early stopping, best iteration is:
# [154]	valid's rmse: 2.15202
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13373
# [200]	valid's rmse: 2.1252
# Early stopping, best iteration is:
# [195]	valid's rmse: 2.12401
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16859
# Early stopping, best iteration is:
# [90]	valid's rmse: 2.1666
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16013
# [200]	valid's rmse: 2.15814
# Early stopping, best iteration is:
# [179]	valid's rmse: 2.15587
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13671
# [200]	valid's rmse: 2.12671
# Early stopping, best iteration is:
# [201]	valid's rmse: 2.12671
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16496
# [200]	valid's rmse: 2.1559
# Early stopping, best iteration is:
# [198]	valid's rmse: 2.15565
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.1575
# [200]	valid's rmse: 2.15934
# Early stopping, best iteration is:
# [150]	valid's rmse: 2.15292
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.1296
# [200]	valid's rmse: 2.12481
# Early stopping, best iteration is:
# [175]	valid's rmse: 2.12227
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.1643
# Early stopping, best iteration is:
# [134]	valid's rmse: 2.15897
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16538
# [200]	valid's rmse: 2.15501
# Early stopping, best iteration is:
# [229]	valid's rmse: 2.15358
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15137
# [200]	valid's rmse: 2.13685
# [300]	valid's rmse: 2.13045
# [400]	valid's rmse: 2.12792
# Early stopping, best iteration is:
# [380]	valid's rmse: 2.12769
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16661
# [200]	valid's rmse: 2.15921
# Early stopping, best iteration is:
# [208]	valid's rmse: 2.15575
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.17508
# [200]	valid's rmse: 2.16571
# Early stopping, best iteration is:
# [242]	valid's rmse: 2.16138
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15925
# [200]	valid's rmse: 2.14506
# [300]	valid's rmse: 2.13684
# [400]	valid's rmse: 2.13199
# Early stopping, best iteration is:
# [419]	valid's rmse: 2.131
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.17177
# [200]	valid's rmse: 2.1675
# Early stopping, best iteration is:
# [162]	valid's rmse: 2.16684
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.1549
# Early stopping, best iteration is:
# [145]	valid's rmse: 2.15238
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.12806
# [200]	valid's rmse: 2.12466
# Early stopping, best iteration is:
# [178]	valid's rmse: 2.12054
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16051
# Early stopping, best iteration is:
# [123]	valid's rmse: 2.15909
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16108
# [200]	valid's rmse: 2.15836
# Early stopping, best iteration is:
# [165]	valid's rmse: 2.15772
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13532
# [200]	valid's rmse: 2.13147
# Early stopping, best iteration is:
# [176]	valid's rmse: 2.13046
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16403
# [200]	valid's rmse: 2.16338
# Early stopping, best iteration is:
# [194]	valid's rmse: 2.16214
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.1604
# [200]	valid's rmse: 2.15528
# Early stopping, best iteration is:
# [207]	valid's rmse: 2.15422
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.1264
# [200]	valid's rmse: 2.12276
# Early stopping, best iteration is:
# [188]	valid's rmse: 2.12154
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16146
# Early stopping, best iteration is:
# [149]	valid's rmse: 2.15993
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15571
# [200]	valid's rmse: 2.15825
# Early stopping, best iteration is:
# [159]	valid's rmse: 2.15332
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13323
# [200]	valid's rmse: 2.13006
# Early stopping, best iteration is:
# [158]	valid's rmse: 2.12894
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.1625
# Early stopping, best iteration is:
# [114]	valid's rmse: 2.1604
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.22257
# [200]	valid's rmse: 2.21433
# [300]	valid's rmse: 2.20935
# [400]	valid's rmse: 2.20835
# Early stopping, best iteration is:
# [354]	valid's rmse: 2.20791
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.19618
# [200]	valid's rmse: 2.18009
# [300]	valid's rmse: 2.17301
# [400]	valid's rmse: 2.16838
# [500]	valid's rmse: 2.16735
# [600]	valid's rmse: 2.16528
# [700]	valid's rmse: 2.16445
# [800]	valid's rmse: 2.16367
# [900]	valid's rmse: 2.16321
# Early stopping, best iteration is:
# [863]	valid's rmse: 2.16281
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.20575
# [200]	valid's rmse: 2.19473
# [300]	valid's rmse: 2.19129
# [400]	valid's rmse: 2.18904
# Early stopping, best iteration is:
# [449]	valid's rmse: 2.18813
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.22039
# [200]	valid's rmse: 2.2153
# [300]	valid's rmse: 2.21253
# [400]	valid's rmse: 2.20962
# [500]	valid's rmse: 2.2086
# Early stopping, best iteration is:
# [484]	valid's rmse: 2.20807
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.19922
# [200]	valid's rmse: 2.18272
# [300]	valid's rmse: 2.1774
# [400]	valid's rmse: 2.17565
# [500]	valid's rmse: 2.17407
# [600]	valid's rmse: 2.17319
# Early stopping, best iteration is:
# [553]	valid's rmse: 2.17305
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.20376
# [200]	valid's rmse: 2.19566
# [300]	valid's rmse: 2.19547
# Early stopping, best iteration is:
# [253]	valid's rmse: 2.1943
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16275
# [200]	valid's rmse: 2.15442
# Early stopping, best iteration is:
# [239]	valid's rmse: 2.15291
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13648
# [200]	valid's rmse: 2.12508
# [300]	valid's rmse: 2.12077
# Early stopping, best iteration is:
# [317]	valid's rmse: 2.12038
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15846
# [200]	valid's rmse: 2.16075
# Early stopping, best iteration is:
# [167]	valid's rmse: 2.15669
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16026
# Early stopping, best iteration is:
# [132]	valid's rmse: 2.15716
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13813
# [200]	valid's rmse: 2.12879
# [300]	valid's rmse: 2.12738
# Early stopping, best iteration is:
# [261]	valid's rmse: 2.12632
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16277
# [200]	valid's rmse: 2.15665
# Early stopping, best iteration is:
# [168]	valid's rmse: 2.15359
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.1518
# Early stopping, best iteration is:
# [144]	valid's rmse: 2.14785
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13309
# [200]	valid's rmse: 2.12947
# Early stopping, best iteration is:
# [186]	valid's rmse: 2.12601
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16106
# [200]	valid's rmse: 2.16023
# Early stopping, best iteration is:
# [150]	valid's rmse: 2.15707
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16324
# [200]	valid's rmse: 2.15959
# Early stopping, best iteration is:
# [171]	valid's rmse: 2.15745
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13909
# [200]	valid's rmse: 2.13264
# Early stopping, best iteration is:
# [228]	valid's rmse: 2.13002
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.17014
# [200]	valid's rmse: 2.16319
# Early stopping, best iteration is:
# [232]	valid's rmse: 2.16204
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15444
# Early stopping, best iteration is:
# [146]	valid's rmse: 2.15213
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.1237
# Early stopping, best iteration is:
# [127]	valid's rmse: 2.12207
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16888
# Early stopping, best iteration is:
# [137]	valid's rmse: 2.16531
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16685
# [200]	valid's rmse: 2.15979
# [300]	valid's rmse: 2.15901
# Early stopping, best iteration is:
# [279]	valid's rmse: 2.1571
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13611
# [200]	valid's rmse: 2.12714
# Early stopping, best iteration is:
# [238]	valid's rmse: 2.12589
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16646
# [200]	valid's rmse: 2.161
# Early stopping, best iteration is:
# [230]	valid's rmse: 2.15961
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.22017
# [200]	valid's rmse: 2.21307
# [300]	valid's rmse: 2.20907
# [400]	valid's rmse: 2.20791
# [500]	valid's rmse: 2.20604
# [600]	valid's rmse: 2.20449
# [700]	valid's rmse: 2.20285
# Early stopping, best iteration is:
# [729]	valid's rmse: 2.20227
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.19136
# [200]	valid's rmse: 2.18034
# [300]	valid's rmse: 2.17366
# [400]	valid's rmse: 2.17177
# [500]	valid's rmse: 2.17052
# [600]	valid's rmse: 2.16961
# Early stopping, best iteration is:
# [551]	valid's rmse: 2.16943
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.20715
# [200]	valid's rmse: 2.19723
# [300]	valid's rmse: 2.19693
# Early stopping, best iteration is:
# [268]	valid's rmse: 2.19582
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15831
# Early stopping, best iteration is:
# [114]	valid's rmse: 2.15681
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.12963
# [200]	valid's rmse: 2.12521
# Early stopping, best iteration is:
# [192]	valid's rmse: 2.12197
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.15998
# Early stopping, best iteration is:
# [142]	valid's rmse: 2.15721
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.1631
# [200]	valid's rmse: 2.15825
# [300]	valid's rmse: 2.15362
# Early stopping, best iteration is:
# [279]	valid's rmse: 2.15301
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13985
# [200]	valid's rmse: 2.13042
# [300]	valid's rmse: 2.12759
# Early stopping, best iteration is:
# [280]	valid's rmse: 2.12607
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.17181
# [200]	valid's rmse: 2.16642
# Early stopping, best iteration is:
# [187]	valid's rmse: 2.16622
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.17238
# [200]	valid's rmse: 2.16737
# [300]	valid's rmse: 2.16434
# Early stopping, best iteration is:
# [317]	valid's rmse: 2.16308
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.16333
# [200]	valid's rmse: 2.14573
# [300]	valid's rmse: 2.13977
# [400]	valid's rmse: 2.13485
# [500]	valid's rmse: 2.13478
# Early stopping, best iteration is:
# [462]	valid's rmse: 2.13395
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.17158
# [200]	valid's rmse: 2.16116
# [300]	valid's rmse: 2.15915
# [400]	valid's rmse: 2.15643
# [500]	valid's rmse: 2.15631
# Early stopping, best iteration is:
# [454]	valid's rmse: 2.1552
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed: 557.1min finished
# Training until validation scores don't improve for 50 rounds.
# [100]	valid's rmse: 2.13096
# Early stopping, best iteration is:
# [120]	valid's rmse: 2.12742
# Best score reached: -2.284002494575311 with params: {'colsample_bytree': 0.5239213632096064, 'min_child_samples': 226, 'min_child_weight': 1, 'num_leaves': 38, 'reg_alpha': 0.1, 'reg_lambda': 20, 'subsample': 0.7352277643328753}

# %%
# Best score reached: -2.493945295968725 with params: {'colsample_bytree': 0.6761597976790243, 'min_child_samples': 281, 'min_child_weight': 100.0, 'num_leaves': 11, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.2970194609775752}

# %%
gs.best_estimator_
# Out:
# LGBMRegressor(boosting_type='gbdt', class_weight=None,
#               colsample_bytree=0.5239213632096064, importance_type='split',
#               learning_rate=0.1, max_depth=-1, metric='rmse',
#               min_child_samples=226, min_child_weight=1, min_split_gain=0.0,
#               n_estimators=5000, n_jobs=-1, num_leaves=38, objective=None,
#               random_state=236, reg_alpha=0.1, reg_lambda=20, silent=True,
#               subsample=0.7352277643328753, subsample_for_bin=200000,
#               subsample_freq=0)

# %%
save_model(gs.best_estimator_, f'/content/drive/My Drive/m5/best_estimator_003.r5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-4b539212a83f> in <module>()
# ----> 1 save_model(gs.best_estimator_, f'/content/drive/My Drive/m5/best_estimator_003.r5')
#
# NameError: name 'save_model' is not defined

# %% [markdown]
# ## Save Model
# Save model to disk, used by the logger to create checkpoints.
#
# Important because we will be running many notebook kernels in parallel.

# %%
import pickle

def save_model(model, fname):
    """Serialize model using given filename
    Args: 
        model (serializeable): Model to save
        fname (str): File name
    Returns:
        None  
    """
    pickle.dump(model, open(fname, 'wb'))

# %%
save_model(model, '/content/drive/My Drive/m5/models/lgbm_217c.pickle')

# %% [markdown]
# ## WRMSSE Scoring
# The M5 uses a unique scoring function that incorporates weights of the last 28 days of the series.
#
# These functions are from the [WRMSSE Evaluator with extra features](https://www.kaggle.com/dhananjay3/wrmsse-evaluator-with-extra-features) notebook.

# %%
from typing import Union

import numpy as np
import pandas as pd
from tqdm.auto import tqdm as tqdm

class WRMSSEEvaluator(object):
    
    group_ids = ( 'all_id', 'state_id', 'store_id', 'cat_id', 'dept_id', 'item_id',
        ['state_id', 'cat_id'],  ['state_id', 'dept_id'], ['store_id', 'cat_id'],
        ['store_id', 'dept_id'], ['item_id', 'state_id'], ['item_id', 'store_id'])

    def __init__(self, 
                 train_df: pd.DataFrame, 
                 valid_df: pd.DataFrame, 
                 calendar: pd.DataFrame, 
                 prices: pd.DataFrame):
        '''
        intialize and calculate weights
        '''
        self.calendar = calendar
        self.prices = prices
        self.train_df = train_df
        self.valid_df = valid_df
        self.train_target_columns = [i for i in self.train_df.columns if i.startswith('d_')]
        self.weight_columns = self.train_df.iloc[:, -28:].columns.tolist()

        self.train_df['all_id'] = "all"

        self.id_columns = [i for i in self.train_df.columns if not i.startswith('d_')]
        self.valid_target_columns = [i for i in self.valid_df.columns if i.startswith('d_')]

        if not all([c in self.valid_df.columns for c in self.id_columns]):
            self.valid_df = pd.concat([self.train_df[self.id_columns], self.valid_df],
                                      axis=1, 
                                      sort=False)
        self.train_series = self.trans_30490_to_42840(self.train_df, 
                                                      self.train_target_columns, 
                                                      self.group_ids)
        self.valid_series = self.trans_30490_to_42840(self.valid_df, 
                                                      self.valid_target_columns, 
                                                      self.group_ids)
        self.weights = self.get_weight_df()
        self.scale = self.get_scale()
        self.train_series = None
        self.train_df = None
        self.prices = None
        self.calendar = None

    def get_scale(self):
        '''
        scaling factor for each series ignoring starting zeros
        '''
        scales = []
        for i in tqdm(range(len(self.train_series))):
            series = self.train_series.iloc[i].values
            series = series[np.argmax(series!=0):]
            scale = ((series[1:] - series[:-1]) ** 2).mean()
            scales.append(scale)
        return np.array(scales)
    
    def get_name(self, i):
        '''
        convert a str or list of strings to unique string 
        used for naming each of 42840 series
        '''
        if type(i) == str or type(i) == int:
            return str(i)
        else:
            return "--".join(i)
    
    def get_weight_df(self) -> pd.DataFrame:
        """
        returns weights for each of 42840 series in a dataFrame
        """
        day_to_week = self.calendar.set_index("d")["wm_yr_wk"].to_dict()
        weight_df = self.train_df[["item_id", "store_id"] + self.weight_columns].set_index(
            ["item_id", "store_id"]
        )
        weight_df = (
            weight_df.stack().reset_index().rename(columns={"level_2": "d", 0: "value"})
        )
        weight_df["wm_yr_wk"] = weight_df["d"].map(day_to_week)
        weight_df = weight_df.merge(
            self.prices, how="left", on=["item_id", "store_id", "wm_yr_wk"]
        )
        weight_df["value"] = weight_df["value"] * weight_df["sell_price"]
        weight_df = weight_df.set_index(["item_id", "store_id", "d"]).unstack(level=2)[
            "value"
        ]
        weight_df = weight_df.loc[
            zip(self.train_df.item_id, self.train_df.store_id), :
        ].reset_index(drop=True)
        weight_df = pd.concat(
            [self.train_df[self.id_columns], weight_df], axis=1, sort=False
        )
        weights_map = {}
        for i, group_id in enumerate(tqdm(self.group_ids, leave=False)):
            lv_weight = weight_df.groupby(group_id)[self.weight_columns].sum().sum(axis=1)
            lv_weight = lv_weight / lv_weight.sum()
            for i in range(len(lv_weight)):
                weights_map[self.get_name(lv_weight.index[i])] = np.array(
                    [lv_weight.iloc[i]]
                )
        weights = pd.DataFrame(weights_map).T / len(self.group_ids)

        return weights

    def trans_30490_to_42840(self, df, cols, group_ids, dis=False):
        '''
        transform 30490 sries to all 42840 series
        '''
        series_map = {}
        for i, group_id in enumerate(tqdm(self.group_ids, leave=False, disable=dis)):
            tr = df.groupby(group_id)[cols].sum()
            for i in range(len(tr)):
                series_map[self.get_name(tr.index[i])] = tr.iloc[i].values
        return pd.DataFrame(series_map).T
    
    def get_rmsse(self, valid_preds) -> pd.Series:
        '''
        returns rmsse scores for all 42840 series
        '''
        score = ((self.valid_series - valid_preds) ** 2).mean(axis=1)
        rmsse = (score / self.scale).map(np.sqrt)
        return rmsse

    def score(self, valid_preds: Union[pd.DataFrame, np.ndarray]) -> float:
        assert self.valid_df[self.valid_target_columns].shape == valid_preds.shape

        if isinstance(valid_preds, np.ndarray):
            valid_preds = pd.DataFrame(valid_preds, columns=self.valid_target_columns)

        valid_preds = pd.concat([self.valid_df[self.id_columns], valid_preds],
                                axis=1, 
                                sort=False)
        valid_preds = self.trans_30490_to_42840(valid_preds, 
                                                self.valid_target_columns, 
                                                self.group_ids, 
                                                True)
        self.rmsse = self.get_rmsse(valid_preds)
        self.contributors = pd.concat([self.weights, self.rmsse], 
                                      axis=1, 
                                      sort=False).prod(axis=1)
        return np.sum(self.contributors)

# %% [markdown]
# ### Example
# Load in our data, create a fake predictions array to pass in and make sure we are getting a score back.

# %%
# !cp /content/drive/My\ Drive/m5/m5-forecasting-accuracy.zip /content

# %%
# !unzip /content/m5-forecasting-accuracy.zip
# Out:
# Archive:  /content/m5-forecasting-accuracy.zip
#   inflating: calendar.csv
#   inflating: sales_train_evaluation.csv
#   inflating: sales_train_validation.csv
#   inflating: sample_submission.csv
#   inflating: sell_prices.csv

# %%
# %%time

train_df = pd.read_csv('./sales_train_validation.csv')
calendar = pd.read_csv('./calendar.csv')
prices = pd.read_csv('./sell_prices.csv')

train_fold_df = train_df.iloc[:, :-28]
valid_fold_df = train_df.iloc[:, -28:].copy()

e = WRMSSEEvaluator(train_fold_df, valid_fold_df, calendar, prices)
del train_fold_df, train_df, calendar, prices

# %% [markdown]
# ## Build Submission
# Take predictions and unmelt them so they are back in wide form.

# %%
X_test_val['sold'] = model.predict(X_test_val[numeric_columns])
X_test_eval['sold'] = model.predict(X_test_eval[numeric_columns])

# e.score(valid_preds)

# %%
X_test_val

# %%
X_test_eval

# %%
submission_df = pd.read_csv('sample_submission.csv')

# %%
submission_df

# %%
submission_df[['id']]

# %%
def predict(test, submission):
    predictions = test[['id', 'date', 'sold']]
    predictions = pd.pivot(predictions, index = 'id', columns = 'date', values = 'sold').reset_index()
    predictions.columns = ['id'] + ['F' + str(i + 1) for i in range(28)]

    evaluation_rows = [row for row in submission['id'] if 'evaluation' in row] 
    evaluation = submission[submission['id'].isin(evaluation_rows)]

    validation = submission[['id']].merge(predictions, on = 'id')
    final = pd.concat([validation, evaluation])
    final.to_csv(f'/content/drive/My Drive/m5/predictions/submission_lgbm_05.csv', index = False)

# %%
predict(X_test_val, submission_df)

# %% [markdown]
# ## Model Log
# Save a pickle of the model and enter the details into the log.

# %%
from datetime import datetime
import os

def log_model(model, score, model_name, description):
    """Save model and create an entry in 'model_log.log'
    Args: 
        model (can predict): Model to score and save
        model_name (str): Name to associate with model
        description (str): Any special information to associated with model
    Returns:
        None
    """
    timestamp = datetime.now()

    path = f'./{model_name}'
    fname = f'{path}/{timestamp.date()}-{timestamp.time()}-{score}.pickle'
    
    try:
      os.listdir(path)
    except:
      os.mkdir(path)
    
    save_model(model, fname)
    
    with open(f'./{model_name}/model_log.log', 'a') as log:
        entry = f"{timestamp}, {description}, {score}, {fname}\n"
        log.write(entry)

# %% [markdown]
# ### Example
# We will load the iris dataset into a stock logistic regression model from sklearn.
#
# Then we can fit it and score its predictions before we try to log it.
#
# The log function will pickle the model and write an entry to our log data frame.

# %%
from sklearn import datasets
test_data = datasets.load_iris()

# %%
X = test_data.data 
y = test_data.target

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X, y)
score = model.score(X, y)

# %%
log_model(model, score, 'logistic_regression', 'score works')

# %%
import pandas as pd
log_df = pd.read_csv('./logistic_regression/model_log.log', names=['timestamp', 'description', 'score', 'filename'])

# %%
log_df.head()
